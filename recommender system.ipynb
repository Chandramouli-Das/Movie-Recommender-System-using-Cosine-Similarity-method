# %% [markdown]
# ## Importing Libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import nltk
from nltk.corpus import stopwords

# %%
import matplotlib.pyplot as plt
pd.options.display.max_columns = None
from scipy import stats
from ast import literal_eval
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import linear_kernel

# %% [markdown]
# ## Reading the Datasets

# %%
stop = stopwords.words('english')    
name_basics = pd.read_csv('name_basics.tsv',sep='\t')
title_basics = pd.read_csv('title_basics.tsv',sep='\t')
title_ratings = pd.read_csv('title_ratings.tsv',sep = '\t')
title_crew = pd.read_csv('title_crew.tsv',sep = '\t')
# Out:
# C:\Users\KIIT\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3147: DtypeWarning: Columns (5) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
name_basics
# Out:
#             nconst         primaryName birthYear deathYear  \
# 0        nm0000001        Fred Astaire      1899      1987
# 1        nm0000002       Lauren Bacall      1924      2014
# 2        nm0000003     Brigitte Bardot      1934        \N
# 3        nm0000004        John Belushi      1949      1982
# 4        nm0000005      Ingmar Bergman      1918      2007
# ...            ...                 ...       ...       ...
# 9949092  nm9993714   Romeo del Rosario        \N        \N
# 9949093  nm9993716       Essias Loberg        \N        \N
# 9949094  nm9993717  Harikrishnan Rajan        \N        \N
# 9949095  nm9993718         Aayush Nair        \N        \N
# 9949096  nm9993719          Andre Hill        \N        \N
#
#                            primaryProfession  \
# 0             soundtrack,actor,miscellaneous
# 1                         actress,soundtrack
# 2                actress,soundtrack,producer
# 3                    actor,soundtrack,writer
# 4                      writer,director,actor
# ...                                      ...
# 9949092  animation_department,art_department
# 9949093                                  NaN
# 9949094                      cinematographer
# 9949095                      cinematographer
# 9949096                                  NaN
#
#                                   knownForTitles
# 0        tt0053137,tt0050419,tt0043044,tt0072308
# 1        tt0038355,tt0117057,tt0037382,tt0071877
# 2        tt0054452,tt0057345,tt0059956,tt0049189
# 3        tt0080455,tt0072562,tt0077975,tt0078723
# 4        tt0083922,tt0069467,tt0050976,tt0050986
# ...                                          ...
# 9949092                                tt2455546
# 9949093                                       \N
# 9949094                                tt8736744
# 9949095                                       \N
# 9949096                                       \N
#
# [9949097 rows x 6 columns]

# %%
title_basics
# Out:
#             tconst  titleType               primaryTitle  \
# 0        tt0000001      short                 Carmencita
# 1        tt0000002      short     Le clown et ses chiens
# 2        tt0000003      short             Pauvre Pierrot
# 3        tt0000004      short                Un bon bock
# 4        tt0000005      short           Blacksmith Scene
# ...            ...        ...                        ...
# 6629732  tt9916848  tvEpisode              Episode #3.17
# 6629733  tt9916850  tvEpisode              Episode #3.19
# 6629734  tt9916852  tvEpisode              Episode #3.20
# 6629735  tt9916856      short                   The Wind
# 6629736  tt9916880  tvEpisode  Horrid Henry Knows It All
#
#                      originalTitle  isAdult startYear endYear runtimeMinutes  \
# 0                       Carmencita        0      1894      \N              1
# 1           Le clown et ses chiens        0      1892      \N              5
# 2                   Pauvre Pierrot        0      1892      \N              4
# 3                      Un bon bock        0      1892      \N             12
# 4                 Blacksmith Scene        0      1893      \N              1
# ...                            ...      ...       ...     ...            ...
# 6629732              Episode #3.17        0      2010      \N             \N
# 6629733              Episode #3.19        0      2010      \N             \N
# 6629734              Episode #3.20        0      2010      \N             \N
# 6629735                   The Wind        0      2015      \N             27
# 6629736  Horrid Henry Knows It All        0      2014      \N             10
#
#                            genres
# 0               Documentary,Short
# 1                 Animation,Short
# 2        Animation,Comedy,Romance
# 3                 Animation,Short
# 4                    Comedy,Short
# ...                           ...
# 6629732       Action,Drama,Family
# 6629733       Action,Drama,Family
# 6629734       Action,Drama,Family
# 6629735                     Short
# 6629736   Animation,Comedy,Family
#
# [6629737 rows x 9 columns]

# %%
title_ratings
# Out:
#             tconst  averageRating  numVotes
# 0        tt0000001            5.6      1590
# 1        tt0000002            6.1       192
# 2        tt0000003            6.5      1254
# 3        tt0000004            6.2       119
# 4        tt0000005            6.1      2015
# ...            ...            ...       ...
# 1037483  tt9916576            6.4        10
# 1037484  tt9916578            8.5        16
# 1037485  tt9916720            5.5        47
# 1037486  tt9916766            6.7        11
# 1037487  tt9916778            6.9        18
#
# [1037488 rows x 3 columns]

# %%
title_crew
# Out:
#             tconst            directors                        writers
# 0        tt0000001            nm0005690                             \N
# 1        tt0000002            nm0721526                             \N
# 2        tt0000003            nm0721526                             \N
# 3        tt0000004            nm0721526                             \N
# 4        tt0000005            nm0005690                             \N
# ...            ...                  ...                            ...
# 6629732  tt9916848  nm5519454,nm5519375  nm6182221,nm1628284,nm2921377
# 6629733  tt9916850  nm5519375,nm5519454  nm6182221,nm1628284,nm2921377
# 6629734  tt9916852  nm5519375,nm5519454  nm6182221,nm1628284,nm2921377
# 6629735  tt9916856           nm10538645                      nm6951431
# 6629736  tt9916880            nm0996406            nm1482639,nm2586970
#
# [6629737 rows x 3 columns]

# %% [markdown]
# # Data Pre-Processing

# %% [markdown]
# ## Putting NaN in the blank spaces

# %%
name_basics.replace(to_replace = r'\N', value = np.nan, inplace = True)
name_basics
# Out:
#             nconst         primaryName birthYear deathYear  \
# 0        nm0000001        Fred Astaire      1899      1987
# 1        nm0000002       Lauren Bacall      1924      2014
# 2        nm0000003     Brigitte Bardot      1934       NaN
# 3        nm0000004        John Belushi      1949      1982
# 4        nm0000005      Ingmar Bergman      1918      2007
# ...            ...                 ...       ...       ...
# 9949092  nm9993714   Romeo del Rosario       NaN       NaN
# 9949093  nm9993716       Essias Loberg       NaN       NaN
# 9949094  nm9993717  Harikrishnan Rajan       NaN       NaN
# 9949095  nm9993718         Aayush Nair       NaN       NaN
# 9949096  nm9993719          Andre Hill       NaN       NaN
#
#                            primaryProfession  \
# 0             soundtrack,actor,miscellaneous
# 1                         actress,soundtrack
# 2                actress,soundtrack,producer
# 3                    actor,soundtrack,writer
# 4                      writer,director,actor
# ...                                      ...
# 9949092  animation_department,art_department
# 9949093                                  NaN
# 9949094                      cinematographer
# 9949095                      cinematographer
# 9949096                                  NaN
#
#                                   knownForTitles
# 0        tt0053137,tt0050419,tt0043044,tt0072308
# 1        tt0038355,tt0117057,tt0037382,tt0071877
# 2        tt0054452,tt0057345,tt0059956,tt0049189
# 3        tt0080455,tt0072562,tt0077975,tt0078723
# 4        tt0083922,tt0069467,tt0050976,tt0050986
# ...                                          ...
# 9949092                                tt2455546
# 9949093                                      NaN
# 9949094                                tt8736744
# 9949095                                      NaN
# 9949096                                      NaN
#
# [9949097 rows x 6 columns]

# %%
title_basics.replace(to_replace = r'\N', value = np.nan, inplace = True)
title_basics
# Out:
#             tconst  titleType               primaryTitle  \
# 0        tt0000001      short                 Carmencita
# 1        tt0000002      short     Le clown et ses chiens
# 2        tt0000003      short             Pauvre Pierrot
# 3        tt0000004      short                Un bon bock
# 4        tt0000005      short           Blacksmith Scene
# ...            ...        ...                        ...
# 6629732  tt9916848  tvEpisode              Episode #3.17
# 6629733  tt9916850  tvEpisode              Episode #3.19
# 6629734  tt9916852  tvEpisode              Episode #3.20
# 6629735  tt9916856      short                   The Wind
# 6629736  tt9916880  tvEpisode  Horrid Henry Knows It All
#
#                      originalTitle  isAdult startYear endYear runtimeMinutes  \
# 0                       Carmencita        0      1894     NaN              1
# 1           Le clown et ses chiens        0      1892     NaN              5
# 2                   Pauvre Pierrot        0      1892     NaN              4
# 3                      Un bon bock        0      1892     NaN             12
# 4                 Blacksmith Scene        0      1893     NaN              1
# ...                            ...      ...       ...     ...            ...
# 6629732              Episode #3.17        0      2010     NaN            NaN
# 6629733              Episode #3.19        0      2010     NaN            NaN
# 6629734              Episode #3.20        0      2010     NaN            NaN
# 6629735                   The Wind        0      2015     NaN             27
# 6629736  Horrid Henry Knows It All        0      2014     NaN             10
#
#                            genres
# 0               Documentary,Short
# 1                 Animation,Short
# 2        Animation,Comedy,Romance
# 3                 Animation,Short
# 4                    Comedy,Short
# ...                           ...
# 6629732       Action,Drama,Family
# 6629733       Action,Drama,Family
# 6629734       Action,Drama,Family
# 6629735                     Short
# 6629736   Animation,Comedy,Family
#
# [6629737 rows x 9 columns]

# %%
title_ratings.replace(to_replace = r'\N', value = np.nan, inplace = True)
title_ratings
# Out:
#             tconst  averageRating  numVotes
# 0        tt0000001            5.6      1590
# 1        tt0000002            6.1       192
# 2        tt0000003            6.5      1254
# 3        tt0000004            6.2       119
# 4        tt0000005            6.1      2015
# ...            ...            ...       ...
# 1037483  tt9916576            6.4        10
# 1037484  tt9916578            8.5        16
# 1037485  tt9916720            5.5        47
# 1037486  tt9916766            6.7        11
# 1037487  tt9916778            6.9        18
#
# [1037488 rows x 3 columns]

# %%
title_crew.replace(to_replace = r'\N', value = np.nan, inplace = True)
title_crew
# Out:
#             tconst            directors                        writers
# 0        tt0000001            nm0005690                            NaN
# 1        tt0000002            nm0721526                            NaN
# 2        tt0000003            nm0721526                            NaN
# 3        tt0000004            nm0721526                            NaN
# 4        tt0000005            nm0005690                            NaN
# ...            ...                  ...                            ...
# 6629732  tt9916848  nm5519454,nm5519375  nm6182221,nm1628284,nm2921377
# 6629733  tt9916850  nm5519375,nm5519454  nm6182221,nm1628284,nm2921377
# 6629734  tt9916852  nm5519375,nm5519454  nm6182221,nm1628284,nm2921377
# 6629735  tt9916856           nm10538645                      nm6951431
# 6629736  tt9916880            nm0996406            nm1482639,nm2586970
#
# [6629737 rows x 3 columns]

# %% [markdown]
# ## Sorting by the column isadult==0

# %%
title_basics = title_basics[title_basics['isAdult']==0]
title_basics
# Out:
#             tconst  titleType               primaryTitle  \
# 0        tt0000001      short                 Carmencita
# 1        tt0000002      short     Le clown et ses chiens
# 2        tt0000003      short             Pauvre Pierrot
# 3        tt0000004      short                Un bon bock
# 4        tt0000005      short           Blacksmith Scene
# ...            ...        ...                        ...
# 6629732  tt9916848  tvEpisode              Episode #3.17
# 6629733  tt9916850  tvEpisode              Episode #3.19
# 6629734  tt9916852  tvEpisode              Episode #3.20
# 6629735  tt9916856      short                   The Wind
# 6629736  tt9916880  tvEpisode  Horrid Henry Knows It All
#
#                      originalTitle  isAdult startYear endYear runtimeMinutes  \
# 0                       Carmencita        0      1894     NaN              1
# 1           Le clown et ses chiens        0      1892     NaN              5
# 2                   Pauvre Pierrot        0      1892     NaN              4
# 3                      Un bon bock        0      1892     NaN             12
# 4                 Blacksmith Scene        0      1893     NaN              1
# ...                            ...      ...       ...     ...            ...
# 6629732              Episode #3.17        0      2010     NaN            NaN
# 6629733              Episode #3.19        0      2010     NaN            NaN
# 6629734              Episode #3.20        0      2010     NaN            NaN
# 6629735                   The Wind        0      2015     NaN             27
# 6629736  Horrid Henry Knows It All        0      2014     NaN             10
#
#                            genres
# 0               Documentary,Short
# 1                 Animation,Short
# 2        Animation,Comedy,Romance
# 3                 Animation,Short
# 4                    Comedy,Short
# ...                           ...
# 6629732       Action,Drama,Family
# 6629733       Action,Drama,Family
# 6629734       Action,Drama,Family
# 6629735                     Short
# 6629736   Animation,Comedy,Family
#
# [6427979 rows x 9 columns]

# %% [markdown]
# ## Merging Title_besic and Title_rating into title

# %%
title = pd.merge(title_basics,title_ratings,on='tconst')
title
# Out:
#             tconst  titleType               primaryTitle  \
# 0        tt0000001      short                 Carmencita
# 1        tt0000002      short     Le clown et ses chiens
# 2        tt0000003      short             Pauvre Pierrot
# 3        tt0000004      short                Un bon bock
# 4        tt0000005      short           Blacksmith Scene
# ...            ...        ...                        ...
# 1019063  tt9916576  tvEpisode           Destinee's Story
# 1019064  tt9916578  tvEpisode  The Trial of Joan Collins
# 1019065  tt9916720      short                  The Nun 2
# 1019066  tt9916766  tvEpisode             Episode #10.15
# 1019067  tt9916778  tvEpisode                     Escape
#
#                      originalTitle  isAdult startYear endYear runtimeMinutes  \
# 0                       Carmencita        0      1894     NaN              1
# 1           Le clown et ses chiens        0      1892     NaN              5
# 2                   Pauvre Pierrot        0      1892     NaN              4
# 3                      Un bon bock        0      1892     NaN             12
# 4                 Blacksmith Scene        0      1893     NaN              1
# ...                            ...      ...       ...     ...            ...
# 1019063           Destinee's Story        0      2019     NaN             85
# 1019064  The Trial of Joan Collins        0      2019     NaN            NaN
# 1019065                  The Nun 2        0      2019     NaN             10
# 1019066             Episode #10.15        0      2019     NaN             43
# 1019067                     Escape        0      2019     NaN            NaN
#
#                              genres  averageRating  numVotes
# 0                 Documentary,Short            5.6      1590
# 1                   Animation,Short            6.1       192
# 2          Animation,Comedy,Romance            6.5      1254
# 3                   Animation,Short            6.2       119
# 4                      Comedy,Short            6.1      2015
# ...                             ...            ...       ...
# 1019063                  Reality-TV            6.4        10
# 1019064  Adventure,Biography,Comedy            8.5        16
# 1019065       Comedy,Horror,Mystery            5.5        47
# 1019066           Family,Reality-TV            6.7        11
# 1019067                       Drama            6.9        18
#
# [1019068 rows x 11 columns]

# %% [markdown]
# ## Dropping four unused columns fron title

# %%
title.drop(['originalTitle','isAdult','endYear','runtimeMinutes'],axis=1,inplace=True)
title
# Out:
#             tconst  titleType               primaryTitle startYear  \
# 0        tt0000001      short                 Carmencita      1894
# 1        tt0000002      short     Le clown et ses chiens      1892
# 2        tt0000003      short             Pauvre Pierrot      1892
# 3        tt0000004      short                Un bon bock      1892
# 4        tt0000005      short           Blacksmith Scene      1893
# ...            ...        ...                        ...       ...
# 1019063  tt9916576  tvEpisode           Destinee's Story      2019
# 1019064  tt9916578  tvEpisode  The Trial of Joan Collins      2019
# 1019065  tt9916720      short                  The Nun 2      2019
# 1019066  tt9916766  tvEpisode             Episode #10.15      2019
# 1019067  tt9916778  tvEpisode                     Escape      2019
#
#                              genres  averageRating  numVotes
# 0                 Documentary,Short            5.6      1590
# 1                   Animation,Short            6.1       192
# 2          Animation,Comedy,Romance            6.5      1254
# 3                   Animation,Short            6.2       119
# 4                      Comedy,Short            6.1      2015
# ...                             ...            ...       ...
# 1019063                  Reality-TV            6.4        10
# 1019064  Adventure,Biography,Comedy            8.5        16
# 1019065       Comedy,Horror,Mystery            5.5        47
# 1019066           Family,Reality-TV            6.7        11
# 1019067                       Drama            6.9        18
#
# [1019068 rows x 7 columns]

# %% [markdown]
# ## drop two columns from name_besic

# %%
name_basics.drop(['birthYear','deathYear'],axis=1,inplace=True)
name_basics
# Out:
#             nconst         primaryName                    primaryProfession  \
# 0        nm0000001        Fred Astaire       soundtrack,actor,miscellaneous
# 1        nm0000002       Lauren Bacall                   actress,soundtrack
# 2        nm0000003     Brigitte Bardot          actress,soundtrack,producer
# 3        nm0000004        John Belushi              actor,soundtrack,writer
# 4        nm0000005      Ingmar Bergman                writer,director,actor
# ...            ...                 ...                                  ...
# 9949092  nm9993714   Romeo del Rosario  animation_department,art_department
# 9949093  nm9993716       Essias Loberg                                  NaN
# 9949094  nm9993717  Harikrishnan Rajan                      cinematographer
# 9949095  nm9993718         Aayush Nair                      cinematographer
# 9949096  nm9993719          Andre Hill                                  NaN
#
#                                   knownForTitles
# 0        tt0053137,tt0050419,tt0043044,tt0072308
# 1        tt0038355,tt0117057,tt0037382,tt0071877
# 2        tt0054452,tt0057345,tt0059956,tt0049189
# 3        tt0080455,tt0072562,tt0077975,tt0078723
# 4        tt0083922,tt0069467,tt0050976,tt0050986
# ...                                          ...
# 9949092                                tt2455546
# 9949093                                      NaN
# 9949094                                tt8736744
# 9949095                                      NaN
# 9949096                                      NaN
#
# [9949097 rows x 4 columns]

# %% [markdown]
# ## making subset of startYear and genres

# %%
title.dropna(subset = ['startYear','genres'],inplace = True)
title
# Out:
#             tconst  titleType               primaryTitle startYear  \
# 0        tt0000001      short                 Carmencita      1894
# 1        tt0000002      short     Le clown et ses chiens      1892
# 2        tt0000003      short             Pauvre Pierrot      1892
# 3        tt0000004      short                Un bon bock      1892
# 4        tt0000005      short           Blacksmith Scene      1893
# ...            ...        ...                        ...       ...
# 1019063  tt9916576  tvEpisode           Destinee's Story      2019
# 1019064  tt9916578  tvEpisode  The Trial of Joan Collins      2019
# 1019065  tt9916720      short                  The Nun 2      2019
# 1019066  tt9916766  tvEpisode             Episode #10.15      2019
# 1019067  tt9916778  tvEpisode                     Escape      2019
#
#                              genres  averageRating  numVotes
# 0                 Documentary,Short            5.6      1590
# 1                   Animation,Short            6.1       192
# 2          Animation,Comedy,Romance            6.5      1254
# 3                   Animation,Short            6.2       119
# 4                      Comedy,Short            6.1      2015
# ...                             ...            ...       ...
# 1019063                  Reality-TV            6.4        10
# 1019064  Adventure,Biography,Comedy            8.5        16
# 1019065       Comedy,Horror,Mystery            5.5        47
# 1019066           Family,Reality-TV            6.7        11
# 1019067                       Drama            6.9        18
#
# [998626 rows x 7 columns]

# %% [markdown]
# ## merging title and title_crew in title

# %%
title = pd.merge(title,title_crew,on='tconst')
title
# Out:
#            tconst  titleType               primaryTitle startYear  \
# 0       tt0000001      short                 Carmencita      1894
# 1       tt0000002      short     Le clown et ses chiens      1892
# 2       tt0000003      short             Pauvre Pierrot      1892
# 3       tt0000004      short                Un bon bock      1892
# 4       tt0000005      short           Blacksmith Scene      1893
# ...           ...        ...                        ...       ...
# 998621  tt9916576  tvEpisode           Destinee's Story      2019
# 998622  tt9916578  tvEpisode  The Trial of Joan Collins      2019
# 998623  tt9916720      short                  The Nun 2      2019
# 998624  tt9916766  tvEpisode             Episode #10.15      2019
# 998625  tt9916778  tvEpisode                     Escape      2019
#
#                             genres  averageRating  numVotes   directors  \
# 0                Documentary,Short            5.6      1590   nm0005690
# 1                  Animation,Short            6.1       192   nm0721526
# 2         Animation,Comedy,Romance            6.5      1254   nm0721526
# 3                  Animation,Short            6.2       119   nm0721526
# 4                     Comedy,Short            6.1      2015   nm0005690
# ...                            ...            ...       ...         ...
# 998621                  Reality-TV            6.4        10         NaN
# 998622  Adventure,Biography,Comedy            8.5        16   nm0373673
# 998623       Comedy,Horror,Mystery            5.5        47  nm10538600
# 998624           Family,Reality-TV            6.7        11         NaN
# 998625                       Drama            6.9        18         NaN
#
#                                         writers
# 0                                           NaN
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
# ...                                         ...
# 998621                                      NaN
# 998622  nm1485603,nm1485604,nm1866876,nm0909144
# 998623                                      NaN
# 998624                                      NaN
# 998625                                      NaN
#
# [998626 rows x 9 columns]

# %% [markdown]
# ## startYear column converted into int type;
# ## Adding a new column 'popularity' in title  which is made of :
# ## (Average Rating/ mean of Average raing) + (numVotes / mean of numVotes)

# %%
title['startYear'] = title['startYear'].astype(int)

title['Popularity'] = title['averageRating']/title['averageRating'].mean()+title['numVotes']/title['numVotes'].mean()

# %% [markdown]
# ## Choose those rows whoes popularity is greater than mean popularity

# %%
title = title[title['Popularity']>=title['Popularity'].mean()]
title
# Out:
#            tconst  titleType                            primaryTitle  \
# 0       tt0000001      short                              Carmencita
# 2       tt0000003      short                          Pauvre Pierrot
# 4       tt0000005      short                        Blacksmith Scene
# 7       tt0000008      short  Edison Kinetoscopic Record of a Sneeze
# 9       tt0000010      short                     Exiting the Factory
# ...           ...        ...                                     ...
# 998175  tt9899086  tvEpisode                                 Vaulter
# 998176  tt9899090  tvEpisode                                 Hunting
# 998235  tt9900782      movie                                  Kaithi
# 998334  tt9906260  tvEpisode                                    Hero
# 998385  tt9908860   tvSeries                              Blown Away
#
#         startYear                      genres  averageRating  numVotes  \
# 0            1894           Documentary,Short            5.6      1590
# 2            1892    Animation,Comedy,Romance            6.5      1254
# 4            1893                Comedy,Short            6.1      2015
# 7            1894           Documentary,Short            5.4      1730
# 9            1895           Documentary,Short            6.9      5710
# ...           ...                         ...            ...       ...
# 998175       2019                       Drama            8.7       818
# 998176       2019                       Drama            9.1       928
# 998235       2019             Action,Thriller            8.6      6003
# 998334       2019  Action,Adventure,Animation            9.9     24319
# 998385       2019                  Reality-TV            6.7      1153
#
#                             directors                        writers  \
# 0                           nm0005690                            NaN
# 2                           nm0721526                            NaN
# 4                           nm0005690                            NaN
# 7                           nm0005690                            NaN
# 9                           nm0525910                            NaN
# ...                               ...                            ...
# 998175                      nm0661238  nm1104036,nm2163353,nm2690539
# 998176                      nm0661238  nm1104036,nm0733988,nm2690539
# 998235                      nm7992231                      nm7992231
# 998334  nm2967345,nm2013928,nm1267452  nm4697729,nm1639992,nm5003154
# 998385                      nm2039645                            NaN
#
#         Popularity
# 0         2.435518
# 2         2.222822
# 4         2.942031
# 7         2.549507
# 9         6.831585
# ...            ...
# 998175    2.096428
# 998176    2.266747
# 998235    7.377225
# 998334   26.271259
# 998385    2.148663
#
# [56051 rows x 10 columns]

# %% [markdown]
# ## Removing tvEpisode and Short catagory rows from the titleType column

# %%
title = title[title['titleType'] != 'tvEpisode']
title = title[title['titleType'] != 'short']
title
# Out:
#            tconst titleType                               primaryTitle  \
# 914     tt0002130     movie                            Dante's Inferno
# 1098    tt0002844     movie  Fantômas: In the Shadow of the Guillotine
# 1132    tt0003037     movie                 Fantomas: The Man in Black
# 1153    tt0003165     movie          Fantômas: The Dead Man Who Killed
# 1191    tt0003419     movie                      The Student of Prague
# ...           ...       ...                                        ...
# 997968  tt9886872     movie                           Munthiri Monchan
# 998070  tt9893806     video             IZZAT feat. BRBN: Another Life
# 998097  tt9894470     movie                                        VFW
# 998235  tt9900782     movie                                     Kaithi
# 998385  tt9908860  tvSeries                                 Blown Away
#
#         startYear                   genres  averageRating  numVotes  \
# 914          1911  Adventure,Drama,Fantasy            7.0      2093
# 1098         1913              Crime,Drama            7.0      1881
# 1132         1913              Crime,Drama            7.0      1310
# 1153         1913      Crime,Drama,Mystery            7.0      1013
# 1191         1913     Drama,Fantasy,Horror            6.5      1696
# ...           ...                      ...            ...       ...
# 997968       2019           Comedy,Romance            9.4       894
# 998070       2018              Music,Short            9.2       898
# 998097       2019            Action,Horror            6.3      1246
# 998235       2019          Action,Thriller            8.6      6003
# 998385       2019               Reality-TV            6.7      1153
#
#                             directors                        writers  \
# 914     nm0655824,nm0209738,nm0078205                      nm0019604
# 1098                        nm0275421  nm0019855,nm0275421,nm0816232
# 1132                        nm0275421  nm0019855,nm0275421,nm0816232
# 1153                        nm0275421  nm0019855,nm0275421,nm0816232
# 1191              nm0753233,nm0917467            nm0263912,nm0210503
# ...                               ...                            ...
# 997968                      nm9295244          nm10525626,nm10525627
# 998070                     nm10528780                            NaN
# 998097                      nm3976308            nm2244274,nm2100227
# 998235                      nm7992231                      nm7992231
# 998385                      nm2039645                            NaN
#
#         Popularity
# 914       3.152141
# 1098      2.935632
# 1132      2.352486
# 1153      2.049168
# 1191      2.674224
# ...            ...
# 997968    2.275507
# 998070    2.250603
# 998097    2.185663
# 998235    7.377225
# 998385    2.148663
#
# [39226 rows x 10 columns]

# %% [markdown]
# ## Making subset of directors and writers column

# %%
title.dropna(subset=['directors','writers'],inplace=True)
title
# Out:
#            tconst titleType                               primaryTitle  \
# 914     tt0002130     movie                            Dante's Inferno
# 1098    tt0002844     movie  Fantômas: In the Shadow of the Guillotine
# 1132    tt0003037     movie                 Fantomas: The Man in Black
# 1153    tt0003165     movie          Fantômas: The Dead Man Who Killed
# 1191    tt0003419     movie                      The Student of Prague
# ...           ...       ...                                        ...
# 997746  tt9876408   tvMovie                          Bottled with Love
# 997758  tt9877170     movie                                     Malang
# 997968  tt9886872     movie                           Munthiri Monchan
# 998097  tt9894470     movie                                        VFW
# 998235  tt9900782     movie                                     Kaithi
#
#         startYear                   genres  averageRating  numVotes  \
# 914          1911  Adventure,Drama,Fantasy            7.0      2093
# 1098         1913              Crime,Drama            7.0      1881
# 1132         1913              Crime,Drama            7.0      1310
# 1153         1913      Crime,Drama,Mystery            7.0      1013
# 1191         1913     Drama,Fantasy,Horror            6.5      1696
# ...           ...                      ...            ...       ...
# 997746       2019            Drama,Romance            7.3      1130
# 997758       2020       Action,Crime,Drama            6.6      2070
# 997968       2019           Comedy,Romance            9.4       894
# 998097       2019            Action,Horror            6.3      1246
# 998235       2019          Action,Thriller            8.6      6003
#
#                             directors                        writers  \
# 914     nm0655824,nm0209738,nm0078205                      nm0019604
# 1098                        nm0275421  nm0019855,nm0275421,nm0816232
# 1132                        nm0275421  nm0019855,nm0275421,nm0816232
# 1153                        nm0275421  nm0019855,nm0275421,nm0816232
# 1191              nm0753233,nm0917467            nm0263912,nm0210503
# ...                               ...                            ...
# 997746                      nm0915838                      nm2797005
# 997758                      nm1887138  nm2748159,nm8457764,nm1887138
# 997968                      nm9295244          nm10525626,nm10525627
# 998097                      nm3976308            nm2244274,nm2100227
# 998235                      nm7992231                      nm7992231
#
#         Popularity
# 914       3.152141
# 1098      2.935632
# 1132      2.352486
# 1153      2.049168
# 1191      2.674224
# ...            ...
# 997746    2.212141
# 997758    3.070674
# 997968    2.275507
# 998097    2.185663
# 998235    7.377225
#
# [37661 rows x 10 columns]

# %% [markdown]
# ## Adding a new column tags in title; tag column is made of adding primaryTitle, genres, director, writers column and then these individual columns are droped from title

# %%
title['primaryTitle'] = title['primaryTitle'].str.lower()

title['primaryTitle'] = title['primaryTitle'].apply(lambda x: ' '.join([word for word in x.split() if word not in (stop)]))
title['primaryTitle'] = title['primaryTitle'].str.lower()
title['primaryTitle'] = title['primaryTitle'].apply(lambda x: ' '.join([word for word in x.split() if word not in (stop)]))

title['tags']=title['primaryTitle'].map(str)+','+title['genres']+','+title['directors'].map(str)+','+title['writers']

title.drop(['primaryTitle','genres','directors','writers'],axis=1,inplace=True)
title
# Out:
#            tconst titleType  startYear  averageRating  numVotes  Popularity  \
# 914     tt0002130     movie       1911            7.0      2093    3.152141
# 1098    tt0002844     movie       1913            7.0      1881    2.935632
# 1132    tt0003037     movie       1913            7.0      1310    2.352486
# 1153    tt0003165     movie       1913            7.0      1013    2.049168
# 1191    tt0003419     movie       1913            6.5      1696    2.674224
# ...           ...       ...        ...            ...       ...         ...
# 997746  tt9876408   tvMovie       2019            7.3      1130    2.212141
# 997758  tt9877170     movie       2020            6.6      2070    3.070674
# 997968  tt9886872     movie       2019            9.4       894    2.275507
# 998097  tt9894470     movie       2019            6.3      1246    2.185663
# 998235  tt9900782     movie       2019            8.6      6003    7.377225
#
#                                                      tags
# 914     dante's inferno,Adventure,Drama,Fantasy,nm0655...
# 1098    fantômas: shadow guillotine,Crime,Drama,nm0275...
# 1132    fantomas: man black,Crime,Drama,nm0275421,nm00...
# 1153    fantômas: dead man killed,Crime,Drama,Mystery,...
# 1191    student prague,Drama,Fantasy,Horror,nm0753233,...
# ...                                                   ...
# 997746     bottled love,Drama,Romance,nm0915838,nm2797005
# 997758  malang,Action,Crime,Drama,nm1887138,nm2748159,...
# 997968  munthiri monchan,Comedy,Romance,nm9295244,nm10...
# 998097    vfw,Action,Horror,nm3976308,nm2244274,nm2100227
# 998235         kaithi,Action,Thriller,nm7992231,nm7992231
#
# [37661 rows x 7 columns]

# %% [markdown]
# ## Saving the final title dataframe in into newframe.tsv file

# %%
#Storing a data into a file 
title.to_csv('preprocessed.csv',sep=',')

# %%
print('-----------------Preprocessing done------------------')
# Out:
# -----------------Preprocessing done------------------

# %%
df = pd.read_csv('preprocessed.csv')
df
# Out:
#           tconst titleType  startYear  averageRating  numVotes  Popularity  \
# 0      tt0002130     movie       1911            7.0      2093    3.152141
# 1      tt0002844     movie       1913            7.0      1881    2.935632
# 2      tt0003037     movie       1913            7.0      1310    2.352486
# 3      tt0003165     movie       1913            7.0      1013    2.049168
# 4      tt0003419     movie       1913            6.5      1696    2.674224
# ...          ...       ...        ...            ...       ...         ...
# 37656  tt9876408   tvMovie       2019            7.3      1130    2.212141
# 37657  tt9877170     movie       2020            6.6      2070    3.070674
# 37658  tt9886872     movie       2019            9.4       894    2.275507
# 37659  tt9894470     movie       2019            6.3      1246    2.185663
# 37660  tt9900782     movie       2019            8.6      6003    7.377225
#
#                                                     tags
# 0      dante's inferno,Adventure,Drama,Fantasy,nm0655...
# 1      fantômas: shadow guillotine,Crime,Drama,nm0275...
# 2      fantomas: man black,Crime,Drama,nm0275421,nm00...
# 3      fantômas: dead man killed,Crime,Drama,Mystery,...
# 4      student prague,Drama,Fantasy,Horror,nm0753233,...
# ...                                                  ...
# 37656     bottled love,Drama,Romance,nm0915838,nm2797005
# 37657  malang,Action,Crime,Drama,nm1887138,nm2748159,...
# 37658  munthiri monchan,Comedy,Romance,nm9295244,nm10...
# 37659    vfw,Action,Horror,nm3976308,nm2244274,nm2100227
# 37660         kaithi,Action,Thriller,nm7992231,nm7992231
#
# [37661 rows x 7 columns]

# %% [markdown]
# # IMPLEMENTATION

# %% [markdown]
# ## Main function steps
#
# ### 1. Reads the final preprocessed value from the newfarme.tsv
# ### 2. Reads the title_basics.tsv dataset
# ### 3. Making a new frame new_df contains the rows whose averageRating is > 7.5 and startYear is > 2000
# ### 4. Computing the TF_IDF matrix based on the term frequency in the 'tags' column
# ### 5. Indexing the new_dataframe to accesses the relavant Titles with their IDs
# ### 6. Making a Recommed function which will recommand similar 10 movies
# ### 7. Creating lookup table for post_processing title_lookup.tsv

# %%
def main(test_title):
    print('----------------Running the recommendation engine-----------------')
    df = pd.read_csv('preprocessed.csv')
   # title_basics = pd.read_csv('title_basics.tsv',sep='\t')
    new_df = df[(df.averageRating >7.5) & (df.startYear >2000)]
    
    #Computing the TF_IDF matrix based on the term frequency in the 'tags' column
    tf = TfidfVectorizer(analyzer='word',ngram_range=(1, 2),min_df=0, stop_words='english')
    tfidf_matrix = tf.fit_transform(new_df['tags'])
    T = tfidf_matrix
    
    #Similarity matrix using the dot product
    cosine_similarity_matrix = linear_kernel(T,T)
    #print(cosine_similarity_matrix)
    
    #Indexing the new_dataframe to accesses the relavant Titles with their IDs
    new_df = new_df.reset_index()
    titles = new_df['tconst']
    indices = pd.Series(new_df.index, index = new_df['tconst'])
    
    #Input: title id
    #Output: 10 similar movies based on the similarity scores
    def recommend(title):
        idx = indices[title]
        sim_scores = list(enumerate(cosine_similarity_matrix[idx]))
        sim_scores = sorted(sim_scores, key=lambda x: x[1], reverse=True)
        sim_scores = sim_scores[1:11]
        movie_indices = [i[0] for i in sim_scores]
        return titles.iloc[movie_indices]
    
    recommendations = recommend(test_title)
    
    # Creating lookup table for post_processing
    title_basics = pd.read_csv('title_basics.tsv',sep='\t')
    title_lookup = title_basics.loc[title_basics['tconst'].isin(new_df['tconst'])]
    title_lookup.drop(['originalTitle','isAdult','endYear','runtimeMinutes'],axis=1,inplace=True)
    
    title_lookup.to_csv('title_lookup.csv',sep=',')
    
    post_process(recommendations)

# %% [markdown]
# # Giving input in the Recommendation model

# %%
test = int(input('Enter tconst of title: '))
# Out:
# Enter tconst of title: 0003037

# %% [markdown]
# # Calling the recommendation model i.e main()

# %%
main(test)
# Out:
# ----------------Running the recommendation engine-----------------
# C:\Users\KIIT\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3338: DtypeWarning: Columns (5) have mixed types.Specify dtype option on import or set low_memory=False.
#   if (await self.run_code(code, result,  async_=asy)):
# C:\Users\KIIT\Anaconda3\lib\site-packages\pandas\core\frame.py:4170: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,
#       Unnamed: 0     tconst titleType     primaryTitle  startYear  \
# 2546     3193739  tt2365873     movie  Kevi Rite Jaish       2012
#
#              genres
# 2546  Comedy,Family
#
#
#      Unnamed: 0     tconst  titleType primaryTitle  startYear  \
# 448      370373  tt0386040  videoGame   The Sims 2       2004
#
#                   genres
# 448  Comedy,Drama,Family
#
#
#       Unnamed: 0     tconst  titleType primaryTitle  startYear  \
# 1431     1981113  tt1176737  videoGame   The Sims 3       2009
#
#                    genres
# 1431  Comedy,Drama,Family
#
#
#       Unnamed: 0     tconst titleType     primaryTitle  startYear  \
# 2469     3121532  tt2283748     movie  OMG: Oh My God!       2012
#
#                     genres
# 2469  Comedy,Drama,Fantasy
#
#
#       Unnamed: 0      tconst titleType primaryTitle  startYear  \
# 1281     1271702  tt10530900  tvSeries       Gullak       2019
#
#                    genres
# 1281  Comedy,Drama,Family
#
#
#       Unnamed: 0     tconst titleType       primaryTitle  startYear  \
# 1994     2595321  tt1723122     movie  All You Can Dream       2012
#
#                    genres
# 1994  Comedy,Drama,Family
#
#
#       Unnamed: 0     tconst titleType     primaryTitle  startYear  \
# 4283     6004322  tt8595766  tvSeries  Yeh Meri Family       2018
#
#                    genres
# 4283  Comedy,Drama,Family
#
#
#       Unnamed: 0     tconst titleType primaryTitle  startYear  \
# 2413     3064039  tt2218988     movie  Ustad Hotel       2012
#
#                    genres
# 2413  Comedy,Drama,Family
#
#
#       Unnamed: 0     tconst titleType primaryTitle  startYear  \
# 3507     4437077  tt5182866  tvSeries   Reply 1988       2015
#
#                    genres
# 3507  Comedy,Drama,Family
#
#
#       Unnamed: 0     tconst titleType       primaryTitle  startYear  \
# 2282     2924007  tt2065924     movie  Anytime, Anywhere       2011
#
#                    genres
# 2282  Comedy,Drama,Family
